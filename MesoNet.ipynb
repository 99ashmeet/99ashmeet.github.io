# %% [markdown]
# <a href="https://colab.research.google.com/github/99ashmeet/99ashmeet.github.io/blob/master/MesoNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/HongguLiu/Deepfake-Detection.git
# Out:
# Cloning into 'Deepfake-Detection'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 108 (delta 34), reused 6 (delta 2), pack-reused 41
# Receiving objects: 100% (108/108), 129.93 MiB | 23.17 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
# !cp /content/drive/MyDrive/minor_project/deepfake_database.zip /content/Deepfake-Detection

# %%
cd Deepfake-Detection
# Out:
# /content/Deepfake-Detection

# %%
# !pwd
# Out:
# /content/Deepfake-Detection

# %%
# !apt install p7zip-full 
!7z x deepfake_database.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 192901191 bytes (184 MiB)
#
# Extracting archive: deepfake_database.zip
# --
# Path = deepfake_database.zip
# Type = zip
# Physical Size = 192901191
#
# Everything is Ok
#
# Folders: 8
# Files: 19464
# Size:       191651221
# Compressed: 192901191

# %%
# !cp /content/drive/MyDrive/minor_project/data_sorting.py /content/Deepfake-Detection

# %%
# !mv /content/Deepfake-Detection/deepfake_database/deepfake_database/validation/fake/* /content/Deepfake-Detection/deepfake_database/deepfake_database/train:test/fake

# %%
# !mv /content/Deepfake-Detection/deepfake_database/deepfake_database/validation/real/* /content/Deepfake-Detection/deepfake_database/deepfake_database/train:test/real

# %%
# !mv /content/Deepfake-Detection/deepfake_database/deepfake_database/train:test/* /content/Deepfake-Detection/deepfake_database

# %%
# !mv /content/Deepfake-Detection/deepfake_database/deepfake_database/fake /content/Deepfake-Detection/data_list/deepfakedetection

# %%
# !mv /content/Deepfake-Detection/deepfake_database/deepfake_database/real /content/Deepfake-Detection/data_list/deepfakedetection

# %%
# !mv /content/Deepfake-Detection/data_sorting.py /content/Deepfake-Detection/data_list

# %%
cd data_list/
# Out:
# /content/Deepfake-Detection/data_list

# %%
# !python data_sorting.py
# Out:
# Files have been successfully moved into the output folder and all information put into a TXT file.

# %%
cat images/images.txt
# Out:
# /content/Deepfake-Detection/data_list/images/real00175.jpg 1
# /content/Deepfake-Detection/data_list/images/real01369.jpg 1
# /content/Deepfake-Detection/data_list/images/real06011.jpg 1
# /content/Deepfake-Detection/data_list/images/real02233.jpg 1
# /content/Deepfake-Detection/data_list/images/real01145.jpg 1
# /content/Deepfake-Detection/data_list/images/real02834.jpg 1
# /content/Deepfake-Detection/data_list/images/99_340.jpg 1
# /content/Deepfake-Detection/data_list/images/real03095.jpg 1
# /content/Deepfake-Detection/data_list/images/real00397.jpg 1
# /content/Deepfake-Detection/data_list/images/real03809.jpg 1
# /content/Deepfake-Detection/data_list/images/63_426.jpg 1
# /content/Deepfake-Detection/data_list/images/92_1512.jpg 1
# /content/Deepfake-Detection/data_list/images/85_198.jpg 1
# /content/Deepfake-Detection/data_list/images/real01482.jpg 1
# /content/Deepfake-Detection/data_list/images/75_48.jpg 1
# /content/Deepfake-Detection/data_list/images/real03989.jpg 1
# ...

# %%
# !shuf images/images.txt --output=splitimage.txt

# %%
# !cat splitimage.txt
# Out:
# /content/Deepfake-Detection/data_list/images/77_195.jpg 0
# /content/Deepfake-Detection/data_list/images/real05273.jpg 1
# /content/Deepfake-Detection/data_list/images/100_4.jpg 1
# /content/Deepfake-Detection/data_list/images/real02679.jpg 1
# /content/Deepfake-Detection/data_list/images/real02957.jpg 1
# /content/Deepfake-Detection/data_list/images/77_195.jpg 0
# /content/Deepfake-Detection/data_list/images/77_195.jpg 0
# /content/Deepfake-Detection/data_list/images/77_195.jpg 0
# /content/Deepfake-Detection/data_list/images/real04208.jpg 1
# /content/Deepfake-Detection/data_list/images/53_228.jpg 1
# /content/Deepfake-Detection/data_list/images/77_195.jpg 0
# /content/Deepfake-Detection/data_list/images/77_195.jpg 0
# /content/Deepfake-Detection/data_list/images/77_195.jpg 0
# /content/Deepfake-Detection/data_list/images/real03083.jpg 1
# /content/Deepfake-Detection/data_list/images/real04678.jpg 1
# /content/Deepfake-Detection/data_list/images/real00871.jpg 1
# ...

# %%
# !split -l 15564 --additional-suffix=.txt splitimage.txt train

# %%
# !split -l 1946 --additional-suffix=.txt trainab.txt validate

# %%
# !cp /content/Deepfake-Detection/data_list/train.txt /content/drive/MyDrive/minor_project/dataset
# !cp /content/Deepfake-Detection/data_list/test.txt /content/drive/MyDrive/minor_project/dataset
# !cp /content/Deepfake-Detection/data_list/validate.txt /content/drive/MyDrive/minor_project/dataset

# %%
cd /content/Deepfake-Detection
# Out:
# /content/Deepfake-Detection

# %%
# !pwd
# Out:
# /content/Deepfake-Detection

# %%
# !python -m pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 20.0MB 1.4MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
# ...

# %%
# !python train_CNN.py
# Out:
# Using dropout 0.5
# Epoch 1/10
# ----------
# iteration 20 train loss: 0.0000 Acc: 1.0000
# iteration 40 train loss: 0.0000 Acc: 1.0000
# iteration 60 train loss: 0.0003 Acc: 1.0000
# iteration 80 train loss: 0.0001 Acc: 1.0000
# iteration 100 train loss: 0.0000 Acc: 1.0000
# iteration 120 train loss: 0.0000 Acc: 1.0000
# iteration 140 train loss: 0.0002 Acc: 1.0000
# iteration 160 train loss: 0.0000 Acc: 1.0000
# iteration 180 train loss: 0.0021 Acc: 0.9688
# iteration 200 train loss: 0.0000 Acc: 1.0000
# iteration 220 train loss: 0.0000 Acc: 1.0000
# iteration 240 train loss: 0.0000 Acc: 1.0000
# iteration 260 train loss: 0.0000 Acc: 1.0000
# iteration 280 train loss: 0.0000 Acc: 1.0000
# iteration 300 train loss: 0.0000 Acc: 1.0000
# iteration 320 train loss: 0.0001 Acc: 1.0000
# iteration 340 train loss: 0.0000 Acc: 1.0000
# iteration 360 train loss: 0.0000 Acc: 1.0000
# iteration 380 train loss: 0.0000 Acc: 1.0000
# iteration 400 train loss: 0.0000 Acc: 1.0000
# ...

# %%
# !python test_CNN.py
# Out:
# Using dropout 0.5
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# Iteration Acc 1.0000
# ...

# %%
# !cp -r /content/Deepfake-Detection/output/MesoNet /content/drive/MyDrive/minor_project
